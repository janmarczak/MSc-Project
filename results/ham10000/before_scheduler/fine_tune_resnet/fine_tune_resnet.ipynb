# %% [markdown]
# # ResNet Experiments

# %% [markdown]
# ### Setup
# 1. Import all files from the framework folder into a google colab environment
# 2. Organise files into the same directory as the framework code
# 3. Mount your google drive
# 4. Make sure to have data images uploaded in your google colab under "images.zip"
# 5. Run the experiments/resnet_exp.py scripts

# %%
# !pip install pytorch-lightning
# !pip install tensorboard

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# Unzip the images data from your google drive to data/HAM10000 directory
# !unzip "gdrive/MyDrive/images.zip" -d "/content/data/HAM10000"

# %%
# %run experiments/resnet_exp.py
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:lightning_fabric.loggers.csv_logs:Missing logger folder: logs/resnet18_0.0001
# --------------------
# resnet18_0.0001
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | model           | Resnet     | 11.7 M
# 1 | train_transform | Sequential | 0
# 2 | eval_transform  | Sequential | 0
# -----------------------------------------------
# 11.7 M    Trainable params
# 0         Non-trainable params
# 11.7 M    Total params
# 46.766    Total estimated model params size (MB)
# ...
