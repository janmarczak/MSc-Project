# %% [markdown]
# # ResNet Experiments

# %% [markdown]
# ### Setup
# 1. Import all files from the framework folder into a google colab environment
# 2. Organise files into the same directory as the framework code
# 3. Mount your google drive
# 4. Make sure to have data images uploaded in your google colab under "images.zip"
# 5. Run the experiments/resnet_exp.py scripts

# %%
# !pip install pytorch-lightning
# !pip install tensorboard

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Unzip the images data from your google drive to data/HAM10000 directory
# !unzip "gdrive/MyDrive/images.zip" -d "/content/data/HAM10000"

# %%
# %run experiments/kd_exp.py
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name                 | Type       | Params
# ----------------------------------------------------
# 0 | model                | Resnet18   | 11.7 M
# 1 | train_transform      | Sequential | 0
# 2 | eval_transform       | Sequential | 0
# 3 | teacher_model        | Resnet     | 11.7 M
# 4 | distillation_loss_fn | KLDivLoss  | 0
# ----------------------------------------------------
# 11.7 M    Trainable params
# 11.7 M    Non-trainable params
# 23.4 M    Total params
# 93.532    Total estimated model params size (MB)
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/loggers/csv_logs.py:188: UserWarning: Experiment logs directory logs/resnet18_fine_tune_kd/version_0 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
#   rank_zero_warn(
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.7609668755595345, 'val/PPV': 0.24404761904761904, 'val/NPV': 0.8524762908324552, 'val/TPR': 0.2265193370165746, 'val/TNR': 0.8643162393162394, 'val/f1': 0.23495702005730656, 'val/auroc': 0.7776006988714171, 'val/accuracy_group_0': 0.8454038997214485, 'val/accuracy_group_1': 0.6090225563909775, 'val/disease_prevalence_group_0': 0.10167130919220056, 'val/disease_prevalence_group_1': 0.2706766917293233, 'val/prevalence_group_0': 0.6427931960608774, 'val/prevalence_group_1': 0.35720680393912263, 'val/auc_group_0': 0.7979186577466284, 'val/auc_group_1': 0.688080692376225, 'val/tpr_group_0': 0.1506849315068493, 'val/tpr_group_1': 0.2777777777777778, 'val/tnr_group_0': 0.924031007751938, 'val/tnr_group_1': 0.7319587628865979, 'val/balanced_acc_group_0': 0.5373579696293936, 'val/balanced_acc_group_1': 0.5048682703321878, 'val/loss': 0.5858872532844543}
# --------------------
# {'train/accuracy': 0.8555290573616167, 'train/PPV': 0.35714285714285715, 'train/NPV': 0.859946815246296, 'train/TPR': 0.022104332449160036, 'train/TNR': 0.9934172030427151, 'train/f1': 0.041631973355537054, 'train/auroc': 0.7689193167290864, 'train/accuracy_group_0': 0.9035224709352767, 'train/accuracy_group_1': 0.7300362976406534, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.7934165784633995, 'train/auc_group_1': 0.6916641705725266, 'train/tpr_group_0': 0.025688073394495414, 'train/tpr_group_1': 0.01877133105802048, 'train/tnr_group_0': 0.9952088922958988, 'train/tnr_group_1': 0.9876390605686032, 'train/balanced_acc_group_0': 0.5104484828451972, 'train/balanced_acc_group_1': 0.5032051958133118, 'train/loss': 0.5299805998802185}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8452982810920121, 'val/PPV': 0.6666666666666666, 'val/NPV': 0.8526315789473684, 'val/TPR': 0.1566265060240964, 'val/TNR': 0.9842041312272175, 'val/f1': 0.25365853658536586, 'val/auroc': 0.8661084190955803, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.7341772151898734, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.85819176504463, 'val/auc_group_1': 0.8339217624629289, 'val/tpr_group_0': 0.07246376811594203, 'val/tpr_group_1': 0.21649484536082475, 'val/tnr_group_0': 0.9917218543046358, 'val/tnr_group_1': 0.9634703196347032, 'val/balanced_acc_group_0': 0.532092811210289, 'val/balanced_acc_group_1': 0.589982582497764, 'val/loss': 0.46394672989845276}
# --------------------
# {'train/accuracy': 0.8582904480984059, 'train/PPV': 0.51, 'train/NPV': 0.8627176814541757, 'train/TPR': 0.04509283819628647, 'train/TNR': 0.9928320655354008, 'train/f1': 0.08285946385052802, 'train/auroc': 0.8093298908002001, 'train/accuracy_group_0': 0.905084157556828, 'train/accuracy_group_1': 0.735934664246824, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8289597406296484, 'train/auc_group_1': 0.7391789045592039, 'train/tpr_group_0': 0.047706422018348627, 'train/tpr_group_1': 0.042662116040955635, 'train/tnr_group_0': 0.9946339593714066, 'train/tnr_group_1': 0.9870210135970334, 'train/balanced_acc_group_0': 0.5211701906948776, 'train/balanced_acc_group_1': 0.5148415648189946, 'train/loss': 0.42858657240867615}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8584428715874621, 'val/PPV': 0.6120689655172413, 'val/NPV': 0.8911798396334479, 'val/TPR': 0.42771084337349397, 'val/TNR': 0.945321992709599, 'val/f1': 0.5035460992907801, 'val/auroc': 0.8627194073987322, 'val/accuracy_group_0': 0.8900445765230312, 'val/accuracy_group_1': 0.7911392405063291, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8484499472118245, 'val/auc_group_1': 0.8371228169279292, 'val/tpr_group_0': 0.30434782608695654, 'val/tpr_group_1': 0.5154639175257731, 'val/tnr_group_0': 0.956953642384106, 'val/tnr_group_1': 0.91324200913242, 'val/balanced_acc_group_0': 0.6306507342355312, 'val/balanced_acc_group_1': 0.7143529633290966, 'val/loss': 0.494828462600708}
# --------------------
# {'train/accuracy': 0.8645663361365633, 'train/PPV': 0.5977443609022557, 'train/NPV': 0.8737826256330347, 'train/TPR': 0.14058355437665782, 'train/TNR': 0.9843475716793446, 'train/f1': 0.22763063707945597, 'train/auroc': 0.8320026758012271, 'train/accuracy_group_0': 0.9069928856498352, 'train/accuracy_group_1': 0.7536297640653358, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.842780635837134, 'train/auc_group_1': 0.7728244957538274, 'train/tpr_group_0': 0.11743119266055047, 'train/tpr_group_1': 0.1621160409556314, 'train/tnr_group_0': 0.9894595630509774, 'train/tnr_group_1': 0.9678615574783683, 'train/balanced_acc_group_0': 0.553445377855764, 'train/balanced_acc_group_1': 0.5649887992169998, 'train/loss': 0.3828299641609192}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8574317492416582, 'val/PPV': 0.654320987654321, 'val/NPV': 0.8755506607929515, 'val/TPR': 0.3192771084337349, 'val/TNR': 0.9659781287970839, 'val/f1': 0.4291497975708502, 'val/auroc': 0.8752872974278645, 'val/accuracy_group_0': 0.8945022288261516, 'val/accuracy_group_1': 0.7784810126582279, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8704770131490547, 'val/auc_group_1': 0.8396177564374147, 'val/tpr_group_0': 0.11594202898550725, 'val/tpr_group_1': 0.4639175257731959, 'val/tnr_group_0': 0.9834437086092715, 'val/tnr_group_1': 0.9178082191780822, 'val/balanced_acc_group_0': 0.5496928687973894, 'val/balanced_acc_group_1': 0.690862872475639, 'val/loss': 0.4127642512321472}
# --------------------
# {'train/accuracy': 0.864315300615037, 'train/PPV': 0.5912408759124088, 'train/NPV': 0.8740413362797348, 'train/TPR': 0.14323607427055704, 'train/TNR': 0.9836161497952018, 'train/f1': 0.23060498220640568, 'train/auroc': 0.8394333013085661, 'train/accuracy_group_0': 0.9062988027069234, 'train/accuracy_group_1': 0.7545372050816697, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.852142724021647, 'train/auc_group_1': 0.7760360196931281, 'train/tpr_group_0': 0.10458715596330276, 'train/tpr_group_1': 0.17918088737201365, 'train/tnr_group_0': 0.9900344959754696, 'train/tnr_group_1': 0.9629171817058096, 'train/balanced_acc_group_0': 0.5473108259693862, 'train/balanced_acc_group_1': 0.5710490345389116, 'train/loss': 0.3468852639198303}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8614762386248737, 'val/PPV': 0.7164179104477612, 'val/NPV': 0.8720173535791758, 'val/TPR': 0.2891566265060241, 'val/TNR': 0.976913730255164, 'val/f1': 0.41201716738197425, 'val/auroc': 0.8612115533824239, 'val/accuracy_group_0': 0.9019316493313522, 'val/accuracy_group_1': 0.7753164556962026, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8551684422689317, 'val/auc_group_1': 0.8240361530857223, 'val/tpr_group_0': 0.14492753623188406, 'val/tpr_group_1': 0.3917525773195876, 'val/tnr_group_0': 0.9884105960264901, 'val/tnr_group_1': 0.9452054794520548, 'val/balanced_acc_group_0': 0.5666690661291871, 'val/balanced_acc_group_1': 0.6684790283858212, 'val/loss': 0.4515208601951599}
# --------------------
# {'train/accuracy': 0.8667001380695368, 'train/PPV': 0.5891472868217055, 'train/NPV': 0.8808707124010554, 'train/TPR': 0.20159151193633953, 'train/TNR': 0.9767407840842598, 'train/f1': 0.3003952569169961, 'train/auroc': 0.8513177751944121, 'train/accuracy_group_0': 0.9054311990282838, 'train/accuracy_group_1': 0.765426497277677, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.863194095245463, 'train/auc_group_1': 0.7932653973852184, 'train/tpr_group_0': 0.1614678899082569, 'train/tpr_group_1': 0.23890784982935154, 'train/tnr_group_0': 0.9831353008815639, 'train/tnr_group_1': 0.9561186650185414, 'train/balanced_acc_group_0': 0.5723015953949104, 'train/balanced_acc_group_1': 0.5975132574239465, 'train/loss': 0.31170862913131714}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8361981799797775, 'val/PPV': 0.7, 'val/NPV': 0.8375893769152196, 'val/TPR': 0.04216867469879518, 'val/TNR': 0.9963547995139733, 'val/f1': 0.07954545454545454, 'val/auroc': 0.8695925866284091, 'val/accuracy_group_0': 0.8989598811292719, 'val/accuracy_group_1': 0.7025316455696202, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8530329206257798, 'val/auc_group_1': 0.8552464341194747, 'val/tpr_group_0': 0.028985507246376812, 'val/tpr_group_1': 0.05154639175257732, 'val/tnr_group_0': 0.9983443708609272, 'val/tnr_group_1': 0.9908675799086758, 'val/balanced_acc_group_0': 0.513664939053652, 'val/balanced_acc_group_1': 0.5212069858306265, 'val/loss': 0.48780685663223267}
# --------------------
# {'train/accuracy': 0.8653194427011422, 'train/PPV': 0.5947712418300654, 'train/NPV': 0.8761258321367967, 'train/TPR': 0.16091954022988506, 'train/TNR': 0.9818607372732592, 'train/f1': 0.2533054975643702, 'train/auroc': 0.8514471806046835, 'train/accuracy_group_0': 0.9064723234426514, 'train/accuracy_group_1': 0.7577132486388385, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8632238089042518, 'train/auc_group_1': 0.7891152014242503, 'train/tpr_group_0': 0.12293577981651377, 'train/tpr_group_1': 0.1962457337883959, 'train/tnr_group_0': 0.9883096972019931, 'train/tnr_group_1': 0.9610630407911002, 'train/balanced_acc_group_0': 0.5556227385092535, 'train/balanced_acc_group_1': 0.578654387289748, 'train/loss': 0.30576860904693604}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8614762386248737, 'val/PPV': 0.6330275229357798, 'val/NPV': 0.8897727272727273, 'val/TPR': 0.41566265060240964, 'val/TNR': 0.951397326852977, 'val/f1': 0.5018181818181817, 'val/auroc': 0.8738892386069186, 'val/accuracy_group_0': 0.8870728083209509, 'val/accuracy_group_1': 0.8069620253164557, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8565121412803531, 'val/auc_group_1': 0.8573647789860189, 'val/tpr_group_0': 0.21739130434782608, 'val/tpr_group_1': 0.5567010309278351, 'val/tnr_group_0': 0.9635761589403974, 'val/tnr_group_1': 0.9178082191780822, 'val/balanced_acc_group_0': 0.5904837316441117, 'val/balanced_acc_group_1': 0.7372546250529586, 'val/loss': 0.5406187772750854}
# --------------------
# {'train/accuracy': 0.8684573867202209, 'train/PPV': 0.608355091383812, 'train/NPV': 0.8815928270042194, 'train/TPR': 0.20601237842617154, 'train/TNR': 0.9780573434757168, 'train/f1': 0.30779392338177014, 'train/auroc': 0.8565483147160273, 'train/accuracy_group_0': 0.9094221759500261, 'train/accuracy_group_1': 0.7613430127041743, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8676043758197628, 'train/auc_group_1': 0.7931715301830515, 'train/tpr_group_0': 0.1761467889908257, 'train/tpr_group_1': 0.23378839590443687, 'train/tnr_group_0': 0.9860099655040245, 'train/tnr_group_1': 0.9524103831891224, 'train/balanced_acc_group_0': 0.5810783772474251, 'train/balanced_acc_group_1': 0.5930993895467797, 'train/loss': 0.30108705163002014}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.840242669362993, 'val/PPV': 0.520618556701031, 'val/NPV': 0.9182389937106918, 'val/TPR': 0.608433734939759, 'val/TNR': 0.8869987849331713, 'val/f1': 0.5611111111111111, 'val/auroc': 0.8772270125459309, 'val/accuracy_group_0': 0.8632986627043091, 'val/accuracy_group_1': 0.7911392405063291, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8666138784912181, 'val/auc_group_1': 0.8552464341194747, 'val/tpr_group_0': 0.4492753623188406, 'val/tpr_group_1': 0.7216494845360825, 'val/tnr_group_0': 0.9105960264900662, 'val/tnr_group_1': 0.821917808219178, 'val/balanced_acc_group_0': 0.6799356944044535, 'val/balanced_acc_group_1': 0.7717836463776302, 'val/loss': 0.4152602255344391}
# --------------------
# {'train/accuracy': 0.8664491025480106, 'train/PPV': 0.5922865013774105, 'train/NPV': 0.8795370857443451, 'train/TPR': 0.1900972590627763, 'train/TNR': 0.978349912229374, 'train/f1': 0.2878179384203481, 'train/auroc': 0.8567466587406661, 'train/accuracy_group_0': 0.9089016137428423, 'train/accuracy_group_1': 0.7554446460980037, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.866542068562949, 'train/auc_group_1': 0.7993119217674878, 'train/tpr_group_0': 0.1724770642201835, 'train/tpr_group_1': 0.20648464163822525, 'train/tnr_group_0': 0.9858183211958604, 'train/tnr_group_1': 0.9542645241038319, 'train/balanced_acc_group_0': 0.5791476927080219, 'train/balanced_acc_group_1': 0.5803745828710286, 'train/loss': 0.28852957487106323}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8351870576339737, 'val/PPV': 0.8, 'val/NPV': 0.8353658536585366, 'val/TPR': 0.024096385542168676, 'val/TNR': 0.9987849331713244, 'val/f1': 0.046783625730994156, 'val/auroc': 0.8690509303312888, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.7025316455696202, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8555283616469911, 'val/auc_group_1': 0.8487972508591064, 'val/tpr_group_0': 0.014492753623188406, 'val/tpr_group_1': 0.030927835051546393, 'val/tnr_group_0': 0.9983443708609272, 'val/tnr_group_1': 1.0, 'val/balanced_acc_group_0': 0.5064185622420578, 'val/balanced_acc_group_1': 0.5154639175257731, 'val/loss': 0.4185987710952759}
# --------------------
# {'train/accuracy': 0.8682063511986946, 'train/PPV': 0.5990220048899756, 'train/NPV': 0.8827732204286849, 'train/TPR': 0.21662245800176835, 'train/TNR': 0.976009362200117, 'train/f1': 0.3181818181818182, 'train/auroc': 0.861932899058865, 'train/accuracy_group_0': 0.9092486552142981, 'train/accuracy_group_1': 0.7608892921960072, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8688565691800788, 'train/auc_group_1': 0.8060935634521192, 'train/tpr_group_0': 0.1761467889908257, 'train/tpr_group_1': 0.25426621160409557, 'train/tnr_group_0': 0.9858183211958604, 'train/tnr_group_1': 0.9443757725587144, 'train/balanced_acc_group_0': 0.5809825550933431, 'train/balanced_acc_group_1': 0.599320992081405, 'train/loss': 0.28361475467681885}
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# Testing: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# --------------------
# {'test/accuracy': 0.8622754491017964, 'test/PPV': 0.5164835164835165, 'test/NPV': 0.8968166849615807, 'test/TPR': 0.3333333333333333, 'test/TNR': 0.9488966318234611, 'test/f1': 0.4051724137931034, 'test/auroc': 0.8445235212230542, 'test/accuracy_group_0': 0.9045643153526971, 'test/accuracy_group_1': 0.7526881720430108, 'test/disease_prevalence_group_0': 0.09681881051175657, 'test/disease_prevalence_group_1': 0.25448028673835127, 'test/prevalence_group_0': 0.7215568862275449, 'test/prevalence_group_1': 0.27844311377245506, 'test/auc_group_0': 0.8843141544519799, 'test/auc_group_1': 0.7321912242686891, 'test/tpr_group_0': 0.2857142857142857, 'test/tpr_group_1': 0.38028169014084506, 'test/tnr_group_0': 0.9709035222052067, 'test/tnr_group_1': 0.8798076923076923, 'test/balanced_acc_group_0': 0.6283089039597463, 'test/balanced_acc_group_1': 0.6300446912242686, 'test/loss': 0.3773208260536194}
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃           Test metric           ┃          DataLoader 0           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │            test/NPV             │       0.8968166708946228        │
# │            test/PPV             │       0.5164835453033447        │
# │            test/TNR             │       0.9488966464996338        │
# │            test/TPR             │       0.3333333432674408        │
# │          test/accuracy          │       0.8622754216194153        │
# │      test/accuracy_group_0      │       0.9045643210411072        │
# │      test/accuracy_group_1      │       0.7526881694793701        │
# │        test/auc_group_0         │       0.8843141544519799        │
# │        test/auc_group_1         │       0.7321912242686891        │
# │           test/auroc            │       0.8445235212230542        │
# │    test/balanced_acc_group_0    │       0.6283089039597463        │
# │    test/balanced_acc_group_1    │       0.6300446912242686        │
# │ test/disease_prevalence_group_0 │       0.09681881051175657       │
# │ test/disease_prevalence_group_1 │       0.25448028673835127       │
# │             test/f1             │       0.4051724076271057        │
# │            test/loss            │       0.3773208260536194        │
# │     test/prevalence_group_0     │       0.7215568862275449        │
# │     test/prevalence_group_1     │       0.27844311377245506       │
# │        test/tnr_group_0         │       0.9709035158157349        │
# │        test/tnr_group_1         │        0.879807710647583        │
# │        test/tpr_group_0         │       0.2857142984867096        │
# │        test/tpr_group_1         │       0.3802816867828369        │
# └─────────────────────────────────┴─────────────────────────────────┘
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=3-step=500.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 353MB/s]
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:lightning_fabric.loggers.csv_logs:Missing logger folder: logs/resnet34_fine_tune_kd
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name                 | Type       | Params
# ----------------------------------------------------
# 0 | model                | Resnet18   | 11.7 M
# 1 | train_transform      | Sequential | 0
# 2 | eval_transform       | Sequential | 0
# 3 | teacher_model        | Resnet     | 21.8 M
# 4 | distillation_loss_fn | KLDivLoss  | 0
# ----------------------------------------------------
# 11.7 M    Trainable params
# 21.8 M    Non-trainable params
# 33.5 M    Total params
# 133.965   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.6929274843330349, 'val/PPV': 0.29336734693877553, 'val/NPV': 0.9089655172413793, 'val/TPR': 0.6353591160220995, 'val/TNR': 0.7040598290598291, 'val/f1': 0.4013961605584643, 'val/auroc': 0.7695790244132786, 'val/accuracy_group_0': 0.7423398328690808, 'val/accuracy_group_1': 0.6040100250626567, 'val/disease_prevalence_group_0': 0.10167130919220056, 'val/disease_prevalence_group_1': 0.2706766917293233, 'val/prevalence_group_0': 0.6427931960608774, 'val/prevalence_group_1': 0.35720680393912263, 'val/auc_group_0': 0.762493363066794, 'val/auc_group_1': 0.744113529336897, 'val/tpr_group_0': 0.4520547945205479, 'val/tpr_group_1': 0.7592592592592593, 'val/tnr_group_0': 0.7751937984496124, 'val/tnr_group_1': 0.5463917525773195, 'val/balanced_acc_group_0': 0.6136242964850802, 'val/balanced_acc_group_1': 0.6528255059182895, 'val/loss': 0.6141963601112366}
# --------------------
# {'train/accuracy': 0.842224174720723, 'train/PPV': 0.3125, 'train/NPV': 0.8655484209146901, 'train/TPR': 0.09283819628647215, 'train/TNR': 0.9662083089526039, 'train/f1': 0.14314928425357873, 'train/auroc': 0.7641533691451975, 'train/accuracy_group_0': 0.8868644803053964, 'train/accuracy_group_1': 0.7254990925589837, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.7790984629774845, 'train/auc_group_1': 0.6940203428156786, 'train/tpr_group_0': 0.07706422018348624, 'train/tpr_group_1': 0.1075085324232082, 'train/tnr_group_0': 0.9714449980835569, 'train/tnr_group_1': 0.9493201483312732, 'train/balanced_acc_group_0': 0.5242546091335216, 'train/balanced_acc_group_1': 0.5284143403772407, 'train/loss': 0.28355056047439575}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8341759352881699, 'val/PPV': 0.5070422535211268, 'val/NPV': 0.8890200708382526, 'val/TPR': 0.43373493975903615, 'val/TNR': 0.9149453219927096, 'val/f1': 0.4675324675324675, 'val/auroc': 0.8272701986561068, 'val/accuracy_group_0': 0.87518573551263, 'val/accuracy_group_1': 0.7468354430379747, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8056435358479701, 'val/auc_group_1': 0.7992750553123381, 'val/tpr_group_0': 0.2608695652173913, 'val/tpr_group_1': 0.5567010309278351, 'val/tnr_group_0': 0.945364238410596, 'val/tnr_group_1': 0.8310502283105022, 'val/balanced_acc_group_0': 0.6031169018139937, 'val/balanced_acc_group_1': 0.6938756296191686, 'val/loss': 0.4546829164028168}
# --------------------
# {'train/accuracy': 0.8511359357349065, 'train/PPV': 0.45439469320066334, 'train/NPV': 0.883623030961434, 'train/TPR': 0.242263483642794, 'train/TNR': 0.9518724400234055, 'train/f1': 0.3160322952710496, 'train/auroc': 0.8181417460689469, 'train/accuracy_group_0': 0.8924171438486899, 'train/accuracy_group_1': 0.7431941923774955, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8296872857188069, 'train/auc_group_1': 0.7517507815235597, 'train/tpr_group_0': 0.1926605504587156, 'train/tpr_group_1': 0.2883959044368601, 'train/tnr_group_0': 0.9655040245304715, 'train/tnr_group_1': 0.9079110012360939, 'train/balanced_acc_group_0': 0.5790822874945936, 'train/balanced_acc_group_1': 0.598153452836477, 'train/loss': 0.2121005356311798}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8422649140546006, 'val/PPV': 0.6785714285714286, 'val/NPV': 0.8470343392299687, 'val/TPR': 0.1144578313253012, 'val/TNR': 0.9890643985419199, 'val/f1': 0.1958762886597938, 'val/auroc': 0.8491926393301028, 'val/accuracy_group_0': 0.8959881129271917, 'val/accuracy_group_1': 0.7278481012658228, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.819320472214224, 'val/auc_group_1': 0.8389116414818999, 'val/tpr_group_0': 0.043478260869565216, 'val/tpr_group_1': 0.16494845360824742, 'val/tnr_group_0': 0.9933774834437086, 'val/tnr_group_1': 0.9771689497716894, 'val/balanced_acc_group_0': 0.5184278721566369, 'val/balanced_acc_group_1': 0.5710587016899684, 'val/loss': 0.27623656392097473}
# --------------------
# {'train/accuracy': 0.8535207731894063, 'train/PPV': 0.47406340057636887, 'train/NPV': 0.8897291351574316, 'train/TPR': 0.29089301503094606, 'train/TNR': 0.9466062024575775, 'train/f1': 0.36054794520547945, 'train/auroc': 0.8328172637811266, 'train/accuracy_group_0': 0.8960610792989763, 'train/accuracy_group_1': 0.7422867513611615, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8449286344727672, 'train/auc_group_1': 0.7645072288292545, 'train/tpr_group_0': 0.23302752293577983, 'train/tpr_group_1': 0.3447098976109215, 'train/tnr_group_0': 0.9653123802223074, 'train/tnr_group_1': 0.8862793572311496, 'train/balanced_acc_group_0': 0.5991699515790436, 'train/balanced_acc_group_1': 0.6154946274210356, 'train/loss': 0.1900779753923416}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8260869565217391, 'val/PPV': 0.48148148148148145, 'val/NPV': 0.8935912938331319, 'val/TPR': 0.46987951807228917, 'val/TNR': 0.8979343863912516, 'val/f1': 0.47560975609756095, 'val/auroc': 0.8398600477243117, 'val/accuracy_group_0': 0.8573551263001485, 'val/accuracy_group_1': 0.759493670886076, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8123380362798733, 'val/auc_group_1': 0.8203643553170457, 'val/tpr_group_0': 0.2753623188405797, 'val/tpr_group_1': 0.6082474226804123, 'val/tnr_group_0': 0.9238410596026491, 'val/tnr_group_1': 0.8264840182648402, 'val/balanced_acc_group_0': 0.5996016892216144, 'val/balanced_acc_group_1': 0.7173657204726263, 'val/loss': 0.414451539516449}
# --------------------
# {'train/accuracy': 0.86004769674909, 'train/PPV': 0.5095011876484561, 'train/NPV': 0.9014736842105263, 'train/TPR': 0.3793103448275862, 'train/TNR': 0.9395845523698069, 'train/f1': 0.43487075519513435, 'train/auroc': 0.8488088235218034, 'train/accuracy_group_0': 0.9005726184279021, 'train/accuracy_group_1': 0.7540834845735027, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8635443296141444, 'train/auc_group_1': 0.7757364883963263, 'train/tpr_group_0': 0.30091743119266057, 'train/tpr_group_1': 0.4522184300341297, 'train/tnr_group_0': 0.9632042928325029, 'train/tnr_group_1': 0.8634116192830655, 'train/balanced_acc_group_0': 0.6320608620125817, 'train/balanced_acc_group_1': 0.6578150246585976, 'train/loss': 0.16356974840164185}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8564206268958544, 'val/PPV': 0.6132075471698113, 'val/NPV': 0.8856172140430351, 'val/TPR': 0.39156626506024095, 'val/TNR': 0.9501822600243013, 'val/f1': 0.47794117647058826, 'val/auroc': 0.8633415801724517, 'val/accuracy_group_0': 0.8915304606240714, 'val/accuracy_group_1': 0.7816455696202531, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8396199251367693, 'val/auc_group_1': 0.8470084263051358, 'val/tpr_group_0': 0.21739130434782608, 'val/tpr_group_1': 0.5154639175257731, 'val/tnr_group_0': 0.9685430463576159, 'val/tnr_group_1': 0.8995433789954338, 'val/balanced_acc_group_0': 0.592967175352721, 'val/balanced_acc_group_1': 0.7075036482606034, 'val/loss': 0.1989963948726654}
# --------------------
# {'train/accuracy': 0.8596711434668005, 'train/PPV': 0.5077658303464755, 'train/NPV': 0.9009817671809257, 'train/TPR': 0.3757736516357206, 'train/TNR': 0.9397308367466355, 'train/f1': 0.43191056910569103, 'train/auroc': 0.8458845587333713, 'train/accuracy_group_0': 0.8950199548846087, 'train/accuracy_group_1': 0.7672413793103449, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8542989862191919, 'train/auc_group_1': 0.7821268409573188, 'train/tpr_group_0': 0.29908256880733947, 'train/tpr_group_1': 0.447098976109215, 'train/tnr_group_0': 0.9572633192794174, 'train/tnr_group_1': 0.8831891223733004, 'train/balanced_acc_group_0': 0.6281729440433784, 'train/balanced_acc_group_1': 0.6651440492412577, 'train/loss': 0.15476468205451965}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8169868554095046, 'val/PPV': 0.46153846153846156, 'val/NPV': 0.9042821158690176, 'val/TPR': 0.5421686746987951, 'val/TNR': 0.8724179829890644, 'val/f1': 0.4986149584487534, 'val/auroc': 0.8472822029307998, 'val/accuracy_group_0': 0.849925705794948, 'val/accuracy_group_1': 0.7468354430379747, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8187206065841252, 'val/auc_group_1': 0.8328861271948406, 'val/tpr_group_0': 0.36231884057971014, 'val/tpr_group_1': 0.6701030927835051, 'val/tnr_group_0': 0.9056291390728477, 'val/tnr_group_1': 0.7808219178082192, 'val/balanced_acc_group_0': 0.633973989826279, 'val/balanced_acc_group_1': 0.7254625052958621, 'val/loss': 0.2956896424293518}
# --------------------
# {'train/accuracy': 0.861679427639011, 'train/PPV': 0.5169988276670574, 'train/NPV': 0.903008152937869, 'train/TPR': 0.38992042440318303, 'train/TNR': 0.9397308367466355, 'train/f1': 0.4445564516129032, 'train/auroc': 0.8524564910685046, 'train/accuracy_group_0': 0.8991844525420788, 'train/accuracy_group_1': 0.7636116152450091, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.861906034510041, 'train/auc_group_1': 0.788720748237617, 'train/tpr_group_0': 0.3302752293577982, 'train/tpr_group_1': 0.4453924914675768, 'train/tnr_group_0': 0.9586048294365658, 'train/tnr_group_1': 0.8788627935723115, 'train/balanced_acc_group_0': 0.6444400293971819, 'train/balanced_acc_group_1': 0.6621276425199442, 'train/loss': 0.14523865282535553}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8240647118301314, 'val/PPV': 0.47959183673469385, 'val/NPV': 0.9092055485498108, 'val/TPR': 0.5662650602409639, 'val/TNR': 0.8760631834750912, 'val/f1': 0.5193370165745856, 'val/auroc': 0.8570027375602043, 'val/accuracy_group_0': 0.8454680534918276, 'val/accuracy_group_1': 0.7784810126582279, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8383961992513678, 'val/auc_group_1': 0.8359459586687379, 'val/tpr_group_0': 0.36231884057971014, 'val/tpr_group_1': 0.711340206185567, 'val/tnr_group_0': 0.9006622516556292, 'val/tnr_group_1': 0.8082191780821918, 'val/balanced_acc_group_0': 0.6314905461176696, 'val/balanced_acc_group_1': 0.7597796921338794, 'val/loss': 0.35014140605926514}
# --------------------
# {'train/accuracy': 0.8619304631605372, 'train/PPV': 0.5175936435868331, 'train/NPV': 0.9047417442845047, 'train/TPR': 0.40318302387267907, 'train/TNR': 0.9378291398478642, 'train/f1': 0.4532803180914513, 'train/auroc': 0.8545113274033191, 'train/accuracy_group_0': 0.900919659899358, 'train/accuracy_group_1': 0.7599818511796733, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8618279702230458, 'train/auc_group_1': 0.7911338736146678, 'train/tpr_group_0': 0.3339449541284404, 'train/tpr_group_1': 0.46757679180887374, 'train/tnr_group_0': 0.9601379839018781, 'train/tnr_group_1': 0.8658838071693449, 'train/balanced_acc_group_0': 0.6470414690151592, 'train/balanced_acc_group_1': 0.6667302994891093, 'train/loss': 0.13924643397331238}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8513650151668352, 'val/PPV': 0.5637583892617449, 'val/NPV': 0.9023809523809524, 'val/TPR': 0.5060240963855421, 'val/TNR': 0.9210206561360875, 'val/f1': 0.5333333333333333, 'val/auroc': 0.8607650529212842, 'val/accuracy_group_0': 0.8722139673105498, 'val/accuracy_group_1': 0.8069620253164557, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8388281025050389, 'val/auc_group_1': 0.8466318316621946, 'val/tpr_group_0': 0.2753623188405797, 'val/tpr_group_1': 0.6701030927835051, 'val/tnr_group_0': 0.9403973509933775, 'val/tnr_group_1': 0.867579908675799, 'val/balanced_acc_group_0': 0.6078798349169786, 'val/balanced_acc_group_1': 0.7688415007296521, 'val/loss': 0.19180163741111755}
# --------------------
# {'train/accuracy': 0.8604242500313795, 'train/PPV': 0.5104052573932092, 'train/NPV': 0.905727246952084, 'train/TPR': 0.4120247568523431, 'train/TNR': 0.934610883557636, 'train/f1': 0.4559686888454012, 'train/auroc': 0.8534385753065764, 'train/accuracy_group_0': 0.898663890334895, 'train/accuracy_group_1': 0.7604355716878403, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8645412316575298, 'train/auc_group_1': 0.7828039504381172, 'train/tpr_group_0': 0.3394495412844037, 'train/tpr_group_1': 0.47952218430034127, 'train/tnr_group_0': 0.9570716749712533, 'train/tnr_group_1': 0.8621755253399258, 'train/balanced_acc_group_0': 0.6482606081278285, 'train/balanced_acc_group_1': 0.6708488548201336, 'train/loss': 0.13706780970096588}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# ...
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8645096056622852, 'val/PPV': 0.7666666666666667, 'val/NPV': 0.8708288482238966, 'val/TPR': 0.27710843373493976, 'val/TNR': 0.982989064398542, 'val/f1': 0.40707964601769914, 'val/auroc': 0.8749286331230145, 'val/accuracy_group_0': 0.9093610698365527, 'val/accuracy_group_1': 0.7689873417721519, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8678855936270276, 'val/auc_group_1': 0.8415007296521206, 'val/tpr_group_0': 0.15942028985507245, 'val/tpr_group_1': 0.36082474226804123, 'val/tnr_group_0': 0.9950331125827815, 'val/tnr_group_1': 0.9497716894977168, 'val/balanced_acc_group_0': 0.5772267012189269, 'val/balanced_acc_group_1': 0.6552982158828791, 'val/loss': 0.19356709718704224}
# --------------------
# {'train/accuracy': 0.8746077569976152, 'train/PPV': 0.6170212765957447, 'train/NPV': 0.8942320680805079, 'train/TPR': 0.3076923076923077, 'train/TNR': 0.9684025746050322, 'train/f1': 0.41061946902654867, 'train/auroc': 0.8684561992757952, 'train/accuracy_group_0': 0.9095956966857539, 'train/accuracy_group_1': 0.7831215970961888, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8734831089278117, 'train/auc_group_1': 0.8149529398363968, 'train/tpr_group_0': 0.23486238532110093, 'train/tpr_group_1': 0.37542662116040953, 'train/tnr_group_0': 0.9800689919509391, 'train/tnr_group_1': 0.930778739184178, 'train/balanced_acc_group_0': 0.60746568863602, 'train/balanced_acc_group_1': 0.6531026801722938, 'train/loss': 0.16171933710575104}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8533872598584429, 'val/PPV': 0.8, 'val/NPV': 0.8553459119496856, 'val/TPR': 0.1686746987951807, 'val/TNR': 0.991494532199271, 'val/f1': 0.27860696517412936, 'val/auroc': 0.86332694081307, 'val/accuracy_group_0': 0.9034175334323923, 'val/accuracy_group_1': 0.7468354430379747, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8533928400038391, 'val/auc_group_1': 0.829732147060208, 'val/tpr_group_0': 0.057971014492753624, 'val/tpr_group_1': 0.24742268041237114, 'val/tnr_group_0': 1.0, 'val/tnr_group_1': 0.9680365296803652, 'val/balanced_acc_group_0': 0.5289855072463768, 'val/balanced_acc_group_1': 0.6077296050463682, 'val/loss': 0.2926977872848511}
# --------------------
# {'train/accuracy': 0.8712187774570102, 'train/PPV': 0.5922671353251318, 'train/NPV': 0.8926736955934036, 'train/TPR': 0.2979664014146773, 'train/TNR': 0.9660620245757753, 'train/f1': 0.3964705882352941, 'train/auroc': 0.868552428786282, 'train/accuracy_group_0': 0.9068193649141072, 'train/accuracy_group_1': 0.7781306715063521, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8803151406036268, 'train/auc_group_1': 0.8060914540767897, 'train/tpr_group_0': 0.24770642201834864, 'train/tpr_group_1': 0.3447098976109215, 'train/tnr_group_0': 0.975661172863166, 'train/tnr_group_1': 0.9351050679851669, 'train/balanced_acc_group_0': 0.6116837974407573, 'train/balanced_acc_group_1': 0.6399074827980442, 'train/loss': 0.15643973648548126}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8554095045500506, 'val/PPV': 0.7674418604651163, 'val/NPV': 0.8594080338266384, 'val/TPR': 0.19879518072289157, 'val/TNR': 0.9878493317132442, 'val/f1': 0.3157894736842105, 'val/auroc': 0.8684726756357142, 'val/accuracy_group_0': 0.9019316493313522, 'val/accuracy_group_1': 0.7563291139240507, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8560322487762742, 'val/auc_group_1': 0.8432424798757238, 'val/tpr_group_0': 0.08695652173913043, 'val/tpr_group_1': 0.27835051546391754, 'val/tnr_group_0': 0.9950331125827815, 'val/tnr_group_1': 0.9680365296803652, 'val/balanced_acc_group_0': 0.540994817160956, 'val/balanced_acc_group_1': 0.6231935225721414, 'val/loss': 0.2275981605052948}
# --------------------
# {'train/accuracy': 0.8705911886531944, 'train/PPV': 0.5862068965517241, 'train/NPV': 0.8929199945850819, 'train/TPR': 0.3006189213085765, 'train/TNR': 0.9648917495611469, 'train/f1': 0.39742840444184685, 'train/auroc': 0.869030342820218, 'train/accuracy_group_0': 0.9068193649141072, 'train/accuracy_group_1': 0.7758620689655172, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8770789891026475, 'train/auc_group_1': 0.8129543067116104, 'train/tpr_group_0': 0.24587155963302754, 'train/tpr_group_1': 0.3515358361774744, 'train/tnr_group_0': 0.97585281717133, 'train/tnr_group_1': 0.9295426452410384, 'train/balanced_acc_group_0': 0.6108621884021788, 'train/balanced_acc_group_1': 0.6405392407092564, 'train/loss': 0.15768946707248688}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8705763397371082, 'val/PPV': 0.7111111111111111, 'val/NPV': 0.8865406006674083, 'val/TPR': 0.3855421686746988, 'val/TNR': 0.968408262454435, 'val/f1': 0.5, 'val/auroc': 0.8765316429753034, 'val/accuracy_group_0': 0.9034175334323923, 'val/accuracy_group_1': 0.8006329113924051, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8645263460984739, 'val/auc_group_1': 0.8513392646989596, 'val/tpr_group_0': 0.2318840579710145, 'val/tpr_group_1': 0.4948453608247423, 'val/tnr_group_0': 0.9801324503311258, 'val/tnr_group_1': 0.9360730593607306, 'val/balanced_acc_group_0': 0.6060082541510702, 'val/balanced_acc_group_1': 0.7154592100927364, 'val/loss': 0.2284490317106247}
# --------------------
# {'train/accuracy': 0.8712187774570102, 'train/PPV': 0.59391771019678, 'train/NPV': 0.8921436285097192, 'train/TPR': 0.29354553492484525, 'train/TNR': 0.966793446459918, 'train/f1': 0.39289940828402364, 'train/auroc': 0.8680976667447884, 'train/accuracy_group_0': 0.9066458441783793, 'train/accuracy_group_1': 0.778584392014519, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8785924516757451, 'train/auc_group_1': 0.8085056341415054, 'train/tpr_group_0': 0.23302752293577983, 'train/tpr_group_1': 0.34982935153583616, 'train/tnr_group_0': 0.9770026830203143, 'train/tnr_group_1': 0.9338689740420272, 'train/balanced_acc_group_0': 0.6050151029780471, 'train/balanced_acc_group_1': 0.6418491627889317, 'train/loss': 0.15545402467250824}
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# Testing: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# --------------------
# {'test/accuracy': 0.873253493013972, 'test/PPV': 0.5897435897435898, 'test/NPV': 0.8971861471861472, 'test/TPR': 0.3262411347517731, 'test/TNR': 0.9628339140534262, 'test/f1': 0.4200913242009133, 'test/auroc': 0.8639632292979464, 'test/accuracy_group_0': 0.9059474412171508, 'test/accuracy_group_1': 0.7885304659498208, 'test/disease_prevalence_group_0': 0.09681881051175657, 'test/disease_prevalence_group_1': 0.25448028673835127, 'test/prevalence_group_0': 0.7215568862275449, 'test/prevalence_group_1': 0.27844311377245506, 'test/auc_group_0': 0.8880113760665063, 'test/auc_group_1': 0.7760021668472372, 'test/tpr_group_0': 0.22857142857142856, 'test/tpr_group_1': 0.4225352112676056, 'test/tnr_group_0': 0.9785604900459418, 'test/tnr_group_1': 0.9134615384615384, 'test/balanced_acc_group_0': 0.6035659593086852, 'test/balanced_acc_group_1': 0.667998374864572, 'test/loss': 0.19272716343402863}
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃           Test metric           ┃          DataLoader 0           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │            test/NPV             │       0.8971861600875854        │
# │            test/PPV             │       0.5897436141967773        │
# │            test/TNR             │       0.9628339409828186        │
# │            test/TPR             │        0.326241135597229        │
# │          test/accuracy          │       0.8732534646987915        │
# │      test/accuracy_group_0      │       0.9059474468231201        │
# │      test/accuracy_group_1      │       0.7885304689407349        │
# │        test/auc_group_0         │       0.8880113760665063        │
# │        test/auc_group_1         │       0.7760021668472372        │
# │           test/auroc            │       0.8639632292979464        │
# │    test/balanced_acc_group_0    │       0.6035659593086852        │
# │    test/balanced_acc_group_1    │        0.667998374864572        │
# │ test/disease_prevalence_group_0 │       0.09681881051175657       │
# │ test/disease_prevalence_group_1 │       0.25448028673835127       │
# │             test/f1             │       0.42009133100509644       │
# │            test/loss            │       0.19272716343402863       │
# │     test/prevalence_group_0     │       0.7215568862275449        │
# │     test/prevalence_group_1     │       0.27844311377245506       │
# │        test/tnr_group_0         │       0.9785605072975159        │
# │        test/tnr_group_1         │       0.9134615659713745        │
# │        test/tpr_group_0         │       0.22857142984867096       │
# │        test/tpr_group_1         │       0.4225352108478546        │
# └─────────────────────────────────┴─────────────────────────────────┘
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=14-step=1875.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
