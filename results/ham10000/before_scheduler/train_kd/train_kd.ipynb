# %% [markdown]
# # ResNet Experiments

# %% [markdown]
# ### Setup
# 1. Import all files from the framework folder into a google colab environment
# 2. Organise files into the same directory as the framework code
# 3. Mount your google drive
# 4. Make sure to have data images uploaded in your google colab under "images.zip"
# 5. Run the experiments/resnet_exp.py scripts

# %%
# !pip install pytorch-lightning
# !pip install tensorboard

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Unzip the images data from your google drive to data/HAM10000 directory
# !unzip "gdrive/MyDrive/images.zip" -d "/content/data/HAM10000"

# %%
# %run experiments/kd_exp.py
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name                 | Type       | Params
# ----------------------------------------------------
# 0 | model                | Resnet18   | 11.7 M
# 1 | train_transform      | Sequential | 0
# 2 | eval_transform       | Sequential | 0
# 3 | teacher_model        | Resnet     | 11.7 M
# 4 | distillation_loss_fn | KLDivLoss  | 0
# ----------------------------------------------------
# 11.7 M    Trainable params
# 11.7 M    Non-trainable params
# 23.4 M    Total params
# 93.532    Total estimated model params size (MB)
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/loggers/csv_logs.py:188: UserWarning: Experiment logs directory logs/resnet18_fine_tune_kd/version_0 exists and is not empty. Previous log files in this directory will be deleted when the new ones are saved!
#   rank_zero_warn(
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.7573858549686661, 'val/PPV': 0.17857142857142858, 'val/NPV': 0.8403275332650972, 'val/TPR': 0.13812154696132597, 'val/TNR': 0.8771367521367521, 'val/f1': 0.15576323987538943, 'val/auroc': 0.7462105114038815, 'val/accuracy_group_0': 0.8481894150417827, 'val/accuracy_group_1': 0.5939849624060151, 'val/disease_prevalence_group_0': 0.10167130919220056, 'val/disease_prevalence_group_1': 0.2706766917293233, 'val/prevalence_group_0': 0.6427931960608774, 'val/prevalence_group_1': 0.35720680393912263, 'val/auc_group_0': 0.7734097908038654, 'val/auc_group_1': 0.6278795978108692, 'val/tpr_group_0': 0.0821917808219178, 'val/tpr_group_1': 0.17592592592592593, 'val/tnr_group_0': 0.9348837209302325, 'val/tnr_group_1': 0.7491408934707904, 'val/balanced_acc_group_0': 0.5085377508760751, 'val/balanced_acc_group_1': 0.46253340969835816, 'val/loss': 0.1492210179567337}
# --------------------
# {'train/accuracy': 0.8492531693234593, 'train/PPV': 0.3333333333333333, 'train/NPV': 0.8632203171329123, 'train/TPR': 0.0618921308576481, 'train/TNR': 0.9795201872440024, 'train/f1': 0.10439970171513796, 'train/auroc': 0.7635223156752182, 'train/accuracy_group_0': 0.8934582682630574, 'train/accuracy_group_1': 0.7336660617059891, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.7733663641382511, 'train/auc_group_1': 0.7038616334158803, 'train/tpr_group_0': 0.047706422018348627, 'train/tpr_group_1': 0.07508532423208192, 'train/tnr_group_0': 0.9817937907244155, 'train/tnr_group_1': 0.9721878862793573, 'train/balanced_acc_group_0': 0.5147501063713821, 'train/balanced_acc_group_1': 0.5236366052557195, 'train/loss': 0.13345272839069366}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8452982810920121, 'val/PPV': 0.6756756756756757, 'val/NPV': 0.851890756302521, 'val/TPR': 0.15060240963855423, 'val/TNR': 0.9854191980558931, 'val/f1': 0.24630541871921185, 'val/auroc': 0.8563220073489582, 'val/accuracy_group_0': 0.9049034175334324, 'val/accuracy_group_1': 0.7183544303797469, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8380602744985124, 'val/auc_group_1': 0.8349573977310174, 'val/tpr_group_0': 0.13043478260869565, 'val/tpr_group_1': 0.16494845360824742, 'val/tnr_group_0': 0.9933774834437086, 'val/tnr_group_1': 0.9634703196347032, 'val/balanced_acc_group_0': 0.5619061330262021, 'val/balanced_acc_group_1': 0.5642093866214754, 'val/loss': 0.0799076110124588}
# --------------------
# {'train/accuracy': 0.8602987322706163, 'train/PPV': 0.5321428571428571, 'train/NPV': 0.8722518537791076, 'train/TPR': 0.1317418213969938, 'train/TNR': 0.9808367466354593, 'train/f1': 0.21119773210489015, 'train/auroc': 0.8246964760856731, 'train/accuracy_group_0': 0.9040430331424605, 'train/accuracy_group_1': 0.7459165154264973, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8371404911017264, 'train/auc_group_1': 0.7613167986432499, 'train/tpr_group_0': 0.10275229357798166, 'train/tpr_group_1': 0.15870307167235495, 'train/tnr_group_0': 0.987734764277501, 'train/tnr_group_1': 0.9585908529048207, 'train/balanced_acc_group_0': 0.5452435289277413, 'train/balanced_acc_group_1': 0.5586469622885878, 'train/loss': 0.06037061661481857}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8432760364004045, 'val/PPV': 0.6774193548387096, 'val/NPV': 0.848643006263048, 'val/TPR': 0.12650602409638553, 'val/TNR': 0.9878493317132442, 'val/f1': 0.2131979695431472, 'val/auroc': 0.8595426664129177, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.7278481012658228, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8472742105768307, 'val/auc_group_1': 0.826248646613002, 'val/tpr_group_0': 0.043478260869565216, 'val/tpr_group_1': 0.18556701030927836, 'val/tnr_group_0': 0.9950331125827815, 'val/tnr_group_1': 0.9680365296803652, 'val/balanced_acc_group_0': 0.5192556867261734, 'val/balanced_acc_group_1': 0.5768017699948218, 'val/loss': 0.0797508955001831}
# --------------------
# {'train/accuracy': 0.8601732145098532, 'train/PPV': 0.5232876712328767, 'train/NPV': 0.8763483293870035, 'train/TPR': 0.16887709991158267, 'train/TNR': 0.9745465184318315, 'train/f1': 0.25534759358288767, 'train/auroc': 0.8386626891802331, 'train/accuracy_group_0': 0.9028283879923651, 'train/accuracy_group_1': 0.7486388384754991, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8509682433073941, 'train/auc_group_1': 0.7744297303796455, 'train/tpr_group_0': 0.11743119266055047, 'train/tpr_group_1': 0.2167235494880546, 'train/tnr_group_0': 0.9848600996550403, 'train/tnr_group_1': 0.9412855377008653, 'train/balanced_acc_group_0': 0.5511456461577954, 'train/balanced_acc_group_1': 0.57900454359446, 'train/loss': 0.052650921046733856}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8513650151668352, 'val/PPV': 0.5612903225806452, 'val/NPV': 0.9052757793764988, 'val/TPR': 0.5240963855421686, 'val/TNR': 0.9173754556500607, 'val/f1': 0.5420560747663551, 'val/auroc': 0.8655814021578415, 'val/accuracy_group_0': 0.8826151560178306, 'val/accuracy_group_1': 0.7848101265822784, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8531049045013918, 'val/auc_group_1': 0.8284140658099138, 'val/tpr_group_0': 0.30434782608695654, 'val/tpr_group_1': 0.6804123711340206, 'val/tnr_group_0': 0.9486754966887417, 'val/tnr_group_1': 0.8310502283105022, 'val/balanced_acc_group_0': 0.6265116613878492, 'val/balanced_acc_group_1': 0.7557312997222614, 'val/loss': 0.05958329141139984}
# --------------------
# {'train/accuracy': 0.8661980670264843, 'train/PPV': 0.583547557840617, 'train/NPV': 0.8807073106360517, 'train/TPR': 0.20070733863837312, 'train/TNR': 0.9763019309537742, 'train/f1': 0.29868421052631583, 'train/auroc': 0.8511711027953638, 'train/accuracy_group_0': 0.9045635953496443, 'train/accuracy_group_1': 0.7658802177858439, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8590057000995144, 'train/auc_group_1': 0.7912414517564768, 'train/tpr_group_0': 0.13027522935779817, 'train/tpr_group_1': 0.26621160409556316, 'train/tnr_group_0': 0.9854350325795324, 'train/tnr_group_1': 0.9468479604449939, 'train/balanced_acc_group_0': 0.5578551309686652, 'train/balanced_acc_group_1': 0.6065297822702785, 'train/loss': 0.042853355407714844}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8604651162790697, 'val/PPV': 0.6320754716981132, 'val/NPV': 0.8878822197055493, 'val/TPR': 0.4036144578313253, 'val/TNR': 0.9526123936816525, 'val/f1': 0.49264705882352944, 'val/auroc': 0.8691314468078877, 'val/accuracy_group_0': 0.8959881129271917, 'val/accuracy_group_1': 0.7848101265822784, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8539687110087341, 'val/auc_group_1': 0.8416890269735913, 'val/tpr_group_0': 0.2463768115942029, 'val/tpr_group_1': 0.5154639175257731, 'val/tnr_group_0': 0.9701986754966887, 'val/tnr_group_1': 0.9041095890410958, 'val/balanced_acc_group_0': 0.6082877435454458, 'val/balanced_acc_group_1': 0.7097867532834345, 'val/loss': 0.04187282174825668}
# --------------------
# {'train/accuracy': 0.8685829044809841, 'train/PPV': 0.603448275862069, 'train/NPV': 0.8828197328395715, 'train/TPR': 0.21662245800176835, 'train/TNR': 0.9764482153306027, 'train/f1': 0.3188028627195836, 'train/auroc': 0.8493472043516432, 'train/accuracy_group_0': 0.9097692174214819, 'train/accuracy_group_1': 0.7608892921960072, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8588156381755462, 'train/auc_group_1': 0.7861051228289254, 'train/tpr_group_0': 0.181651376146789, 'train/tpr_group_1': 0.24914675767918087, 'train/tnr_group_0': 0.9858183211958604, 'train/tnr_group_1': 0.946229913473424, 'train/balanced_acc_group_0': 0.5837348486713247, 'train/balanced_acc_group_1': 0.5976883355763024, 'train/loss': 0.040651362389326096}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8584428715874621, 'val/PPV': 0.6226415094339622, 'val/NPV': 0.8867497168742922, 'val/TPR': 0.39759036144578314, 'val/TNR': 0.951397326852977, 'val/f1': 0.4852941176470588, 'val/auroc': 0.8703831120350174, 'val/accuracy_group_0': 0.8959881129271917, 'val/accuracy_group_1': 0.7784810126582279, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8579278241673866, 'val/auc_group_1': 0.8401826484018264, 'val/tpr_group_0': 0.2463768115942029, 'val/tpr_group_1': 0.5051546391752577, 'val/tnr_group_0': 0.9701986754966887, 'val/tnr_group_1': 0.8995433789954338, 'val/balanced_acc_group_0': 0.6082877435454458, 'val/balanced_acc_group_1': 0.7023490090853457, 'val/loss': 0.05504459887742996}
# --------------------
# {'train/accuracy': 0.865193924940379, 'train/PPV': 0.5686746987951807, 'train/NPV': 0.8814883474576272, 'train/TPR': 0.20866489832007074, 'train/TNR': 0.9738150965476887, 'train/f1': 0.3053040103492885, 'train/auroc': 0.859994210708482, 'train/accuracy_group_0': 0.9075134478570189, 'train/accuracy_group_1': 0.7545372050816697, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8673800289048846, 'train/auc_group_1': 0.8000386015685315, 'train/tpr_group_0': 0.1577981651376147, 'train/tpr_group_1': 0.25597269624573377, 'train/tnr_group_0': 0.9858183211958604, 'train/tnr_group_1': 0.9351050679851669, 'train/balanced_acc_group_0': 0.5718082431667375, 'train/balanced_acc_group_1': 0.5955388821154504, 'train/loss': 0.03553260862827301}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8554095045500506, 'val/PPV': 0.5934959349593496, 'val/NPV': 0.8926096997690531, 'val/TPR': 0.4397590361445783, 'val/TNR': 0.9392466585662211, 'val/f1': 0.5051903114186852, 'val/auroc': 0.8707856944180122, 'val/accuracy_group_0': 0.8855869242199108, 'val/accuracy_group_1': 0.7911392405063291, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8568720606584125, 'val/auc_group_1': 0.841594878312856, 'val/tpr_group_0': 0.2463768115942029, 'val/tpr_group_1': 0.5773195876288659, 'val/tnr_group_0': 0.9586092715231788, 'val/tnr_group_1': 0.8858447488584474, 'val/balanced_acc_group_0': 0.6024930415586909, 'val/balanced_acc_group_1': 0.7315821682436567, 'val/loss': 0.042381152510643005}
# --------------------
# {'train/accuracy': 0.8658215137441948, 'train/PPV': 0.5738095238095238, 'train/NPV': 0.8820723466277991, 'train/TPR': 0.21308576480990274, 'train/TNR': 0.9738150965476887, 'train/f1': 0.3107672469374597, 'train/auroc': 0.8553922671827879, 'train/accuracy_group_0': 0.9085545722713865, 'train/accuracy_group_1': 0.7540834845735027, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8678744360558547, 'train/auc_group_1': 0.7887302404266, 'train/tpr_group_0': 0.1779816513761468, 'train/tpr_group_1': 0.24573378839590443, 'train/tnr_group_0': 0.9848600996550403, 'train/tnr_group_1': 0.9381953028430161, 'train/balanced_acc_group_0': 0.5814208755155935, 'train/balanced_acc_group_1': 0.5919645456194602, 'train/loss': 0.04123888537287712}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8634984833164813, 'val/PPV': 0.6597938144329897, 'val/NPV': 0.8856502242152466, 'val/TPR': 0.3855421686746988, 'val/TNR': 0.959902794653706, 'val/f1': 0.48669201520912553, 'val/auroc': 0.8729449999268032, 'val/accuracy_group_0': 0.8989598811292719, 'val/accuracy_group_1': 0.7879746835443038, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8610711200691046, 'val/auc_group_1': 0.8465847573318269, 'val/tpr_group_0': 0.2318840579710145, 'val/tpr_group_1': 0.4948453608247423, 'val/tnr_group_0': 0.9751655629139073, 'val/tnr_group_1': 0.9178082191780822, 'val/balanced_acc_group_0': 0.6035248104424609, 'val/balanced_acc_group_1': 0.7063267900014123, 'val/loss': 0.04567686468362808}
# --------------------
# {'train/accuracy': 0.8672022091125894, 'train/PPV': 0.5839080459770115, 'train/NPV': 0.883563462559745, 'train/TPR': 0.22458001768346597, 'train/TNR': 0.9735225277940316, 'train/f1': 0.3243933588761175, 'train/auroc': 0.8569676373947877, 'train/accuracy_group_0': 0.9085545722713865, 'train/accuracy_group_1': 0.7590744101633394, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8692676374300675, 'train/auc_group_1': 0.7895085999232186, 'train/tpr_group_0': 0.181651376146789, 'train/tpr_group_1': 0.2645051194539249, 'train/tnr_group_0': 0.9844768110387121, 'train/tnr_group_1': 0.9381953028430161, 'train/balanced_acc_group_0': 0.5830640935927506, 'train/balanced_acc_group_1': 0.6013502111484705, 'train/loss': 0.036789003759622574}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8574317492416582, 'val/PPV': 0.6470588235294118, 'val/NPV': 0.8772123893805309, 'val/TPR': 0.3313253012048193, 'val/TNR': 0.9635479951397327, 'val/f1': 0.43824701195219123, 'val/auroc': 0.8670453380960049, 'val/accuracy_group_0': 0.8959881129271917, 'val/accuracy_group_1': 0.7753164556962026, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8537047701314906, 'val/auc_group_1': 0.8396177564374147, 'val/tpr_group_0': 0.15942028985507245, 'val/tpr_group_1': 0.4536082474226804, 'val/tnr_group_0': 0.9801324503311258, 'val/tnr_group_1': 0.9178082191780822, 'val/balanced_acc_group_0': 0.5697763700930991, 'val/balanced_acc_group_1': 0.6857082333003813, 'val/loss': 0.04449494183063507}
# --------------------
# {'train/accuracy': 0.8658215137441948, 'train/PPV': 0.5731132075471698, 'train/NPV': 0.8822749569136948, 'train/TPR': 0.21485411140583555, 'train/TNR': 0.9735225277940316, 'train/f1': 0.312540192926045, 'train/auroc': 0.8537292686195049, 'train/accuracy_group_0': 0.9061252819711956, 'train/accuracy_group_1': 0.7604355716878403, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8616292930962336, 'train/auc_group_1': 0.7927322527706645, 'train/tpr_group_0': 0.1651376146788991, 'train/tpr_group_1': 0.26109215017064846, 'train/tnr_group_0': 0.983518589497892, 'train/tnr_group_1': 0.9412855377008653, 'train/balanced_acc_group_0': 0.5743281020883955, 'train/balanced_acc_group_1': 0.6011888439357569, 'train/loss': 0.0359659306704998}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8604651162790697, 'val/PPV': 0.6521739130434783, 'val/NPV': 0.8818283166109253, 'val/TPR': 0.3614457831325301, 'val/TNR': 0.9611178614823815, 'val/f1': 0.4651162790697674, 'val/auroc': 0.8716567363012195, 'val/accuracy_group_0': 0.9019316493313522, 'val/accuracy_group_1': 0.7721518987341772, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8612390824455322, 'val/auc_group_1': 0.8355222896954291, 'val/tpr_group_0': 0.2028985507246377, 'val/tpr_group_1': 0.4742268041237113, 'val/tnr_group_0': 0.9817880794701986, 'val/tnr_group_1': 0.9041095890410958, 'val/balanced_acc_group_0': 0.5923433150974182, 'val/balanced_acc_group_1': 0.6891681965824036, 'val/loss': 0.04562687501311302}
# --------------------
# {'train/accuracy': 0.8654449604619053, 'train/PPV': 0.5681293302540416, 'train/NPV': 0.8825325192460844, 'train/TPR': 0.21750663129973474, 'train/TNR': 0.9726448215330603, 'train/f1': 0.31457800511508954, 'train/auroc': 0.8609754542317444, 'train/accuracy_group_0': 0.9062988027069234, 'train/accuracy_group_1': 0.7586206896551724, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8658697311001791, 'train/auc_group_1': 0.8063762197462845, 'train/tpr_group_0': 0.1706422018348624, 'train/tpr_group_1': 0.26109215017064846, 'train/tnr_group_0': 0.9831353008815639, 'train/tnr_group_1': 0.9388133498145859, 'train/balanced_acc_group_0': 0.5768887513582132, 'train/balanced_acc_group_1': 0.5999527499926172, 'train/loss': 0.035882845520973206}
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# Testing: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# --------------------
# {'test/accuracy': 0.8552894211576846, 'test/PPV': 0.4830508474576271, 'test/NPV': 0.9049773755656109, 'test/TPR': 0.40425531914893614, 'test/TNR': 0.9291521486643438, 'test/f1': 0.44015444015444016, 'test/auroc': 0.8470852793634318, 'test/accuracy_group_0': 0.8948824343015215, 'test/accuracy_group_1': 0.7526881720430108, 'test/disease_prevalence_group_0': 0.09681881051175657, 'test/disease_prevalence_group_1': 0.25448028673835127, 'test/prevalence_group_0': 0.7215568862275449, 'test/prevalence_group_1': 0.27844311377245506, 'test/auc_group_0': 0.8856486545613651, 'test/auc_group_1': 0.740249187432286, 'test/tpr_group_0': 0.32857142857142857, 'test/tpr_group_1': 0.4788732394366197, 'test/tnr_group_0': 0.9555895865237366, 'test/tnr_group_1': 0.8461538461538461, 'test/balanced_acc_group_0': 0.6420805075475826, 'test/balanced_acc_group_1': 0.6625135427952329, 'test/loss': 0.03956058621406555}
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃           Test metric           ┃          DataLoader 0           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │            test/NPV             │       0.9049773812294006        │
# │            test/PPV             │       0.4830508530139923        │
# │            test/TNR             │       0.9291521310806274        │
# │            test/TPR             │       0.40425533056259155       │
# │          test/accuracy          │       0.8552893996238708        │
# │      test/accuracy_group_0      │       0.8948824405670166        │
# │      test/accuracy_group_1      │       0.7526881694793701        │
# │        test/auc_group_0         │       0.8856486545613651        │
# │        test/auc_group_1         │        0.740249187432286        │
# │           test/auroc            │       0.8470852793634318        │
# │    test/balanced_acc_group_0    │       0.6420805075475826        │
# │    test/balanced_acc_group_1    │       0.6625135427952329        │
# │ test/disease_prevalence_group_0 │       0.09681881051175657       │
# │ test/disease_prevalence_group_1 │       0.25448028673835127       │
# │             test/f1             │       0.44015443325042725       │
# │            test/loss            │       0.03956058621406555       │
# │     test/prevalence_group_0     │       0.7215568862275449        │
# │     test/prevalence_group_1     │       0.27844311377245506       │
# │        test/tnr_group_0         │       0.9555895924568176        │
# │        test/tnr_group_1         │       0.8461538553237915        │
# │        test/tpr_group_0         │       0.3285714387893677        │
# │        test/tpr_group_1         │       0.47887325286865234       │
# └─────────────────────────────────┴─────────────────────────────────┘
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet18_fine_tune_kd/version_0/checkpoints/epoch=4-step=625.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# WARNING:lightning_fabric.loggers.csv_logs:Missing logger folder: logs/resnet34_fine_tune_kd
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name                 | Type       | Params
# ----------------------------------------------------
# 0 | model                | Resnet18   | 11.7 M
# 1 | train_transform      | Sequential | 0
# 2 | eval_transform       | Sequential | 0
# 3 | teacher_model        | Resnet     | 21.8 M
# 4 | distillation_loss_fn | KLDivLoss  | 0
# ----------------------------------------------------
# 11.7 M    Trainable params
# 21.8 M    Non-trainable params
# 33.5 M    Total params
# 133.965   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8263205013428827, 'val/PPV': 0.37254901960784315, 'val/NPV': 0.8480300187617261, 'val/TPR': 0.10497237569060773, 'val/TNR': 0.9658119658119658, 'val/f1': 0.16379310344827583, 'val/auroc': 0.7595386504226282, 'val/accuracy_group_0': 0.8955431754874652, 'val/accuracy_group_1': 0.7017543859649122, 'val/disease_prevalence_group_0': 0.10167130919220056, 'val/disease_prevalence_group_1': 0.2706766917293233, 'val/prevalence_group_0': 0.6427931960608774, 'val/prevalence_group_1': 0.35720680393912263, 'val/auc_group_0': 0.7839439311882765, 'val/auc_group_1': 0.65168003054601, 'val/tpr_group_0': 0.0684931506849315, 'val/tpr_group_1': 0.12962962962962962, 'val/tnr_group_0': 0.9891472868217054, 'val/tnr_group_1': 0.9140893470790378, 'val/balanced_acc_group_0': 0.5288202187533184, 'val/balanced_acc_group_1': 0.5218594883543337, 'val/loss': 0.19836314022541046}
# --------------------
# {'train/accuracy': 0.8512614534956696, 'train/PPV': 0.3701923076923077, 'train/NPV': 0.8641577522876659, 'train/TPR': 0.0680813439434129, 'train/TNR': 0.9808367466354593, 'train/f1': 0.11501120238984316, 'train/auroc': 0.7722034074559246, 'train/accuracy_group_0': 0.8931112267916016, 'train/accuracy_group_1': 0.7418330308529946, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.7848942088254842, 'train/auc_group_1': 0.7130047207819877, 'train/tpr_group_0': 0.045871559633027525, 'train/tpr_group_1': 0.08873720136518772, 'train/tnr_group_0': 0.9816021464162514, 'train/tnr_group_1': 0.9783683559950557, 'train/balanced_acc_group_0': 0.5137368530246395, 'train/balanced_acc_group_1': 0.5335527786801217, 'train/loss': 0.17324724793434143}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8513650151668352, 'val/PPV': 0.6862745098039216, 'val/NPV': 0.8603411513859275, 'val/TPR': 0.21084337349397592, 'val/TNR': 0.9805589307411907, 'val/f1': 0.32258064516129037, 'val/auroc': 0.8642492204541129, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.7531645569620253, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8607831845666569, 'val/auc_group_1': 0.8337334651414584, 'val/tpr_group_0': 0.14492753623188406, 'val/tpr_group_1': 0.25773195876288657, 'val/tnr_group_0': 0.9834437086092715, 'val/tnr_group_1': 0.9726027397260274, 'val/balanced_acc_group_0': 0.5641856224205778, 'val/balanced_acc_group_1': 0.6151673492444569, 'val/loss': 0.10793649405241013}
# --------------------
# {'train/accuracy': 0.8582904480984059, 'train/PPV': 0.5032467532467533, 'train/NPV': 0.8725682203943074, 'train/TPR': 0.13704686118479223, 'train/TNR': 0.9776184903452312, 'train/f1': 0.21542738012508686, 'train/auroc': 0.8206907933709248, 'train/accuracy_group_0': 0.9028283879923651, 'train/accuracy_group_1': 0.7418330308529946, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8262004142330185, 'train/auc_group_1': 0.7688166826276066, 'train/tpr_group_0': 0.13211009174311927, 'train/tpr_group_1': 0.1416382252559727, 'train/tnr_group_0': 0.9833269451897279, 'train/tnr_group_1': 0.9592088998763906, 'train/balanced_acc_group_0': 0.5577185184664235, 'train/balanced_acc_group_1': 0.5504235625661816, 'train/loss': 0.09158547222614288}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8554095045500506, 'val/PPV': 0.7254901960784313, 'val/NPV': 0.8624733475479744, 'val/TPR': 0.22289156626506024, 'val/TNR': 0.982989064398542, 'val/f1': 0.34101382488479265, 'val/auroc': 0.8686703069873662, 'val/accuracy_group_0': 0.8989598811292719, 'val/accuracy_group_1': 0.7626582278481012, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8599193780593147, 'val/auc_group_1': 0.8388645671515322, 'val/tpr_group_0': 0.08695652173913043, 'val/tpr_group_1': 0.31958762886597936, 'val/tnr_group_0': 0.9917218543046358, 'val/tnr_group_1': 0.958904109589041, 'val/balanced_acc_group_0': 0.5393391880218831, 'val/balanced_acc_group_1': 0.6392458692275103, 'val/loss': 0.15784135460853577}
# --------------------
# {'train/accuracy': 0.8640642650935108, 'train/PPV': 0.5538116591928252, 'train/NPV': 0.8824624385055179, 'train/TPR': 0.21839080459770116, 'train/TNR': 0.9708894090111176, 'train/f1': 0.31325301204819284, 'train/auroc': 0.8402403875255513, 'train/accuracy_group_0': 0.9059517612354676, 'train/accuracy_group_1': 0.7545372050816697, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.849940045221024, 'train/auc_group_1': 0.7787339107396736, 'train/tpr_group_0': 0.1926605504587156, 'train/tpr_group_1': 0.24232081911262798, 'train/tnr_group_0': 0.9804522805672672, 'train/tnr_group_1': 0.9400494437577256, 'train/balanced_acc_group_0': 0.5865564155129914, 'train/balanced_acc_group_1': 0.5911851314351768, 'train/loss': 0.06533455103635788}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8483316481294236, 'val/PPV': 0.5571428571428572, 'val/NPV': 0.8963486454652533, 'val/TPR': 0.46987951807228917, 'val/TNR': 0.9246658566221142, 'val/f1': 0.5098039215686274, 'val/auroc': 0.8695413488705734, 'val/accuracy_group_0': 0.87518573551263, 'val/accuracy_group_1': 0.7911392405063291, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8679095882522315, 'val/auc_group_1': 0.8296850727298404, 'val/tpr_group_0': 0.30434782608695654, 'val/tpr_group_1': 0.5876288659793815, 'val/tnr_group_0': 0.9403973509933775, 'val/tnr_group_1': 0.8812785388127854, 'val/balanced_acc_group_0': 0.622372588540167, 'val/balanced_acc_group_1': 0.7344537023960834, 'val/loss': 0.06705869734287262}
# --------------------
# {'train/accuracy': 0.863436676289695, 'train/PPV': 0.5485327313769752, 'train/NPV': 0.8819776714513556, 'train/TPR': 0.21485411140583555, 'train/TNR': 0.970743124634289, 'train/f1': 0.3087674714104193, 'train/auroc': 0.8486154591156508, 'train/accuracy_group_0': 0.9056047197640118, 'train/accuracy_group_1': 0.7531760435571688, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8594505258790145, 'train/auc_group_1': 0.7867010213595347, 'train/tpr_group_0': 0.1798165137614679, 'train/tpr_group_1': 0.24744027303754265, 'train/tnr_group_0': 0.9814105021080873, 'train/tnr_group_1': 0.9363411619283065, 'train/balanced_acc_group_0': 0.5806135079347776, 'train/balanced_acc_group_1': 0.5918907174829245, 'train/loss': 0.0650528222322464}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8483316481294236, 'val/PPV': 0.6, 'val/NPV': 0.8701870187018702, 'val/TPR': 0.2891566265060241, 'val/TNR': 0.9611178614823815, 'val/f1': 0.3902439024390244, 'val/auroc': 0.8721032367623593, 'val/accuracy_group_0': 0.8900445765230312, 'val/accuracy_group_1': 0.759493670886076, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8728044917938382, 'val/auc_group_1': 0.8290731064350609, 'val/tpr_group_0': 0.14492753623188406, 'val/tpr_group_1': 0.3917525773195876, 'val/tnr_group_0': 0.9751655629139073, 'val/tnr_group_1': 0.9223744292237442, 'val/balanced_acc_group_0': 0.5600465495728957, 'val/balanced_acc_group_1': 0.657063503271666, 'val/loss': 0.09666125476360321}
# --------------------
# {'train/accuracy': 0.8719718840215891, 'train/PPV': 0.6121212121212121, 'train/NPV': 0.889186295503212, 'train/TPR': 0.26790450928381965, 'train/TNR': 0.9719133996489175, 'train/f1': 0.3726937269372694, 'train/auroc': 0.8614465778768355, 'train/accuracy_group_0': 0.9113309040430332, 'train/accuracy_group_1': 0.7690562613430127, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8737869266934148, 'train/auc_group_1': 0.7960793040748912, 'train/tpr_group_0': 0.22385321100917432, 'train/tpr_group_1': 0.30887372013651876, 'train/tnr_group_0': 0.9831353008815639, 'train/tnr_group_1': 0.9357231149567367, 'train/balanced_acc_group_0': 0.6034942559453691, 'train/balanced_acc_group_1': 0.6222984175466277, 'train/loss': 0.0454106330871582}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8523761375126391, 'val/PPV': 0.6388888888888888, 'val/NPV': 0.8691384950926936, 'val/TPR': 0.27710843373493976, 'val/TNR': 0.968408262454435, 'val/f1': 0.38655462184873945, 'val/auroc': 0.8722642697155573, 'val/accuracy_group_0': 0.8945022288261516, 'val/accuracy_group_1': 0.7626582278481012, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8740762069296478, 'val/auc_group_1': 0.8257308289789578, 'val/tpr_group_0': 0.13043478260869565, 'val/tpr_group_1': 0.38144329896907214, 'val/tnr_group_0': 0.9817880794701986, 'val/tnr_group_1': 0.9315068493150684, 'val/balanced_acc_group_0': 0.5561114310394472, 'val/balanced_acc_group_1': 0.6564750741420703, 'val/loss': 0.04615528881549835}
# --------------------
# {'train/accuracy': 0.8695870465670893, 'train/PPV': 0.5909090909090909, 'train/NPV': 0.8884867980163517, 'train/TPR': 0.26436781609195403, 'train/TNR': 0.9697191339964891, 'train/f1': 0.36530238240684176, 'train/auroc': 0.8645962835749159, 'train/accuracy_group_0': 0.9101162588929377, 'train/accuracy_group_1': 0.7636116152450091, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8723873957824186, 'train/auc_group_1': 0.8052508680079481, 'train/tpr_group_0': 0.22752293577981653, 'train/tpr_group_1': 0.2986348122866894, 'train/tnr_group_0': 0.9814105021080873, 'train/tnr_group_1': 0.9320148331273177, 'train/balanced_acc_group_0': 0.6044667189439519, 'train/balanced_acc_group_1': 0.6153248227070036, 'train/loss': 0.04370800778269768}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8523761375126391, 'val/PPV': 0.7083333333333334, 'val/NPV': 0.8597236981934112, 'val/TPR': 0.20481927710843373, 'val/TNR': 0.982989064398542, 'val/f1': 0.3177570093457944, 'val/auroc': 0.8748920347245605, 'val/accuracy_group_0': 0.8989598811292719, 'val/accuracy_group_1': 0.7531645569620253, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8692292926384491, 'val/auc_group_1': 0.8399002024196206, 'val/tpr_group_0': 0.07246376811594203, 'val/tpr_group_1': 0.29896907216494845, 'val/tnr_group_0': 0.9933774834437086, 'val/tnr_group_1': 0.954337899543379, 'val/balanced_acc_group_0': 0.5329206257798254, 'val/balanced_acc_group_1': 0.6266534858541637, 'val/loss': 0.06287627667188644}
# --------------------
# {'train/accuracy': 0.8733525793899837, 'train/PPV': 0.619140625, 'train/NPV': 0.8908115358819584, 'train/TPR': 0.28028293545534927, 'train/TNR': 0.9714745465184318, 'train/f1': 0.3858794887401095, 'train/auroc': 0.8688253377474742, 'train/accuracy_group_0': 0.9108103418358494, 'train/accuracy_group_1': 0.7754083484573503, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8803995344274055, 'train/auc_group_1': 0.8071461417415847, 'train/tpr_group_0': 0.24220183486238533, 'train/tpr_group_1': 0.31569965870307165, 'train/tnr_group_0': 0.9806439248754312, 'train/tnr_group_1': 0.9419035846724351, 'train/balanced_acc_group_0': 0.6114228798689083, 'train/balanced_acc_group_1': 0.6288016216877533, 'train/loss': 0.038616541773080826}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# ...
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8321536905965622, 'val/PPV': 0.0, 'val/NPV': 0.8321536905965622, 'val/TPR': 0.0, 'val/TNR': 1.0, 'val/f1': 0.0, 'val/auroc': 0.8166347040653501, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.6930379746835443, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8074671273634706, 'val/auc_group_1': 0.7794096878971898, 'val/tpr_group_0': 0.0, 'val/tpr_group_1': 0.0, 'val/tnr_group_0': 1.0, 'val/tnr_group_1': 1.0, 'val/balanced_acc_group_0': 0.5, 'val/balanced_acc_group_1': 0.5, 'val/loss': 0.05455084145069122}
# --------------------
# {'train/accuracy': 0.8580394125768797, 'train/PPV': 0.0, 'train/NPV': 0.8580394125768797, 'train/TPR': 0.0, 'train/TNR': 1.0, 'train/f1': 0.0, 'train/auroc': 0.8140344015326362, 'train/accuracy_group_0': 0.9054311990282838, 'train/accuracy_group_1': 0.7341197822141561, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8263885421318583, 'train/auc_group_1': 0.7422744128553771, 'train/tpr_group_0': 0.0, 'train/tpr_group_1': 0.0, 'train/tnr_group_0': 1.0, 'train/tnr_group_1': 1.0, 'train/balanced_acc_group_0': 0.5, 'train/balanced_acc_group_1': 0.5, 'train/loss': 0.04280174523591995}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8321536905965622, 'val/PPV': 0.0, 'val/NPV': 0.8321536905965622, 'val/TPR': 0.0, 'val/TNR': 1.0, 'val/f1': 0.0, 'val/auroc': 0.8284559867660191, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.6930379746835443, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8073231596122469, 'val/auc_group_1': 0.8069481711622652, 'val/tpr_group_0': 0.0, 'val/tpr_group_1': 0.0, 'val/tnr_group_0': 1.0, 'val/tnr_group_1': 1.0, 'val/balanced_acc_group_0': 0.5, 'val/balanced_acc_group_1': 0.5, 'val/loss': 0.05980244278907776}
# --------------------
# {'train/accuracy': 0.8579138948161165, 'train/PPV': 0.0, 'train/NPV': 0.8580215917650013, 'train/TPR': 0.0, 'train/TNR': 0.9998537156231715, 'train/f1': 0.0, 'train/auroc': 0.8169643573136238, 'train/accuracy_group_0': 0.9054311990282838, 'train/accuracy_group_1': 0.7336660617059891, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8248648819717211, 'train/auc_group_1': 0.7590903529828676, 'train/tpr_group_0': 0.0, 'train/tpr_group_1': 0.0, 'train/tnr_group_0': 1.0, 'train/tnr_group_1': 0.9993819530284301, 'train/balanced_acc_group_0': 0.5, 'train/balanced_acc_group_1': 0.49969097651421507, 'train/loss': 0.041822366416454315}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8321536905965622, 'val/PPV': 0.0, 'val/NPV': 0.8321536905965622, 'val/TPR': 0.0, 'val/TNR': 1.0, 'val/f1': 0.0, 'val/auroc': 0.8368809380901492, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.6930379746835443, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8198723485939149, 'val/auc_group_1': 0.8124087934849127, 'val/tpr_group_0': 0.0, 'val/tpr_group_1': 0.0, 'val/tnr_group_0': 1.0, 'val/tnr_group_1': 1.0, 'val/balanced_acc_group_0': 0.5, 'val/balanced_acc_group_1': 0.5, 'val/loss': 0.055284541100263596}
# --------------------
# {'train/accuracy': 0.8580394125768797, 'train/PPV': 0.0, 'train/NPV': 0.8580394125768797, 'train/TPR': 0.0, 'train/TNR': 1.0, 'train/f1': 0.0, 'train/auroc': 0.8130947410572519, 'train/accuracy_group_0': 0.9054311990282838, 'train/accuracy_group_1': 0.7341197822141561, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.824550866619078, 'train/auc_group_1': 0.7455407805532469, 'train/tpr_group_0': 0.0, 'train/tpr_group_1': 0.0, 'train/tnr_group_0': 1.0, 'train/tnr_group_1': 1.0, 'train/balanced_acc_group_0': 0.5, 'train/balanced_acc_group_1': 0.5, 'train/loss': 0.04305192083120346}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8321536905965622, 'val/PPV': 0.0, 'val/NPV': 0.8321536905965622, 'val/TPR': 0.0, 'val/TNR': 1.0, 'val/f1': 0.0, 'val/auroc': 0.8378178570905738, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.6930379746835443, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8257750263940877, 'val/auc_group_1': 0.8130678341100599, 'val/tpr_group_0': 0.0, 'val/tpr_group_1': 0.0, 'val/tnr_group_0': 1.0, 'val/tnr_group_1': 1.0, 'val/balanced_acc_group_0': 0.5, 'val/balanced_acc_group_1': 0.5, 'val/loss': 0.060516566038131714}
# --------------------
# {'train/accuracy': 0.8580394125768797, 'train/PPV': 0.0, 'train/NPV': 0.8580394125768797, 'train/TPR': 0.0, 'train/TNR': 1.0, 'train/f1': 0.0, 'train/auroc': 0.814039575162232, 'train/accuracy_group_0': 0.9054311990282838, 'train/accuracy_group_1': 0.7341197822141561, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.8216241591386203, 'train/auc_group_1': 0.7511084767356995, 'train/tpr_group_0': 0.0, 'train/tpr_group_1': 0.0, 'train/tnr_group_0': 1.0, 'train/tnr_group_1': 1.0, 'train/balanced_acc_group_0': 0.5, 'train/balanced_acc_group_1': 0.5, 'train/loss': 0.04275314509868622}
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# Validation: 0it [00:00, ?it/s]
# --------------------
# {'val/accuracy': 0.8321536905965622, 'val/PPV': 0.0, 'val/NPV': 0.8321536905965622, 'val/TPR': 0.0, 'val/TNR': 1.0, 'val/f1': 0.0, 'val/auroc': 0.8245692368501955, 'val/accuracy_group_0': 0.8974739970282318, 'val/accuracy_group_1': 0.6930379746835443, 'val/disease_prevalence_group_0': 0.1025260029717682, 'val/disease_prevalence_group_1': 0.3069620253164557, 'val/prevalence_group_0': 0.6804853387259858, 'val/prevalence_group_1': 0.3195146612740142, 'val/auc_group_0': 0.8127939341587485, 'val/auc_group_1': 0.7907546015157935, 'val/tpr_group_0': 0.0, 'val/tpr_group_1': 0.0, 'val/tnr_group_0': 1.0, 'val/tnr_group_1': 1.0, 'val/balanced_acc_group_0': 0.5, 'val/balanced_acc_group_1': 0.5, 'val/loss': 0.052472978830337524}
# --------------------
# {'train/accuracy': 0.8580394125768797, 'train/PPV': 0.0, 'train/NPV': 0.8580394125768797, 'train/TPR': 0.0, 'train/TNR': 1.0, 'train/f1': 0.0, 'train/auroc': 0.8155968376706457, 'train/accuracy_group_0': 0.9054311990282838, 'train/accuracy_group_1': 0.7341197822141561, 'train/disease_prevalence_group_0': 0.09456880097171612, 'train/disease_prevalence_group_1': 0.2658802177858439, 'train/prevalence_group_0': 0.7233588552780218, 'train/prevalence_group_1': 0.27664114472197815, 'train/auc_group_0': 0.823739982628938, 'train/auc_group_1': 0.7528613676345886, 'train/tpr_group_0': 0.0, 'train/tpr_group_1': 0.0, 'train/tnr_group_0': 1.0, 'train/tnr_group_1': 1.0, 'train/balanced_acc_group_0': 0.5, 'train/balanced_acc_group_1': 0.5, 'train/loss': 0.04176679626107216}
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# Testing: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# --------------------
# {'test/accuracy': 0.8592814371257484, 'test/PPV': 0.0, 'test/NPV': 0.8592814371257484, 'test/TPR': 0.0, 'test/TNR': 1.0, 'test/f1': 0.0, 'test/auroc': 0.7838897537911549, 'test/accuracy_group_0': 0.9031811894882434, 'test/accuracy_group_1': 0.7455197132616488, 'test/disease_prevalence_group_0': 0.09681881051175657, 'test/disease_prevalence_group_1': 0.25448028673835127, 'test/prevalence_group_0': 0.7215568862275449, 'test/prevalence_group_1': 0.27844311377245506, 'test/auc_group_0': 0.7994749507766353, 'test/auc_group_1': 0.6986728060671723, 'test/tpr_group_0': 0.0, 'test/tpr_group_1': 0.0, 'test/tnr_group_0': 1.0, 'test/tnr_group_1': 1.0, 'test/balanced_acc_group_0': 0.5, 'test/balanced_acc_group_1': 0.5, 'test/loss': 0.047242671251297}
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃           Test metric           ┃          DataLoader 0           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │            test/NPV             │       0.8592814207077026        │
# │            test/PPV             │               0.0               │
# │            test/TNR             │               1.0               │
# │            test/TPR             │               0.0               │
# │          test/accuracy          │       0.8592814207077026        │
# │      test/accuracy_group_0      │       0.9031811952590942        │
# │      test/accuracy_group_1      │       0.7455196976661682        │
# │        test/auc_group_0         │       0.7994749507766353        │
# │        test/auc_group_1         │       0.6986728060671723        │
# │           test/auroc            │       0.7838897537911549        │
# │    test/balanced_acc_group_0    │               0.5               │
# │    test/balanced_acc_group_1    │               0.5               │
# │ test/disease_prevalence_group_0 │       0.09681881051175657       │
# │ test/disease_prevalence_group_1 │       0.25448028673835127       │
# │             test/f1             │               0.0               │
# │            test/loss            │        0.047242671251297        │
# │     test/prevalence_group_0     │       0.7215568862275449        │
# │     test/prevalence_group_1     │       0.27844311377245506       │
# │        test/tnr_group_0         │               1.0               │
# │        test/tnr_group_1         │               1.0               │
# │        test/tpr_group_0         │               0.0               │
# │        test/tpr_group_1         │               0.0               │
# └─────────────────────────────────┴─────────────────────────────────┘
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
# INFO:pytorch_lightning.utilities.rank_zero:Restoring states from the checkpoint path at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:Loaded model weights from the checkpoint at logs/resnet152_fine_tune_kd/version_0/checkpoints/epoch=16-step=2125.ckpt
# Predicting: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:2919: UserWarning: reduction: 'mean' divides the total loss by both the batch size and the support size.'batchmean' divides only by the batch size, and aligns with the KL div math definition.'mean' will be changed to behave the same as 'batchmean' in the next major release.
#   warnings.warn(
